# %%
import numpy as np
from bayspec import Plot
from bayspec.model.local import *
from bayspec.model.astro import *
from bayspec.model.xspec import *

# %% [markdown]
# local models

# %%
local_models
# Out:
# {'pl': bayspec.model.local.additive.pl,
#  'cpl': bayspec.model.local.additive.cpl,
#  'sbpl': bayspec.model.local.additive.sbpl,
#  'csbpl': bayspec.model.local.additive.csbpl,
#  'dsbpl': bayspec.model.local.additive.dsbpl,
#  'tsbpl': bayspec.model.local.additive.tsbpl,
#  'sb2pl': bayspec.model.local.additive.sb2pl,
#  'csb2pl': bayspec.model.local.additive.csb2pl,
#  'sb3pl': bayspec.model.local.additive.sb3pl,
#  'sb4pl': bayspec.model.local.additive.sb4pl,
#  'band': bayspec.model.local.additive.band,
#  'cband': bayspec.model.local.additive.cband,
#  'dband': bayspec.model.local.additive.dband,
#  'bb': bayspec.model.local.additive.bb,
#  'mbb': bayspec.model.local.additive.mbb,
#  'hlecpl': bayspec.model.local.additive.hlecpl,
#  'hleband': bayspec.model.local.additive.hleband,
#  'zxhsync': bayspec.model.local.additive.zxhsync,
#  'katu': bayspec.model.local.additive.katu,
#  'const': bayspec.model.local.mathematic.const,
# ...

# %%
bb_ins = bb()
bb_ins
# Out:
# *** Model ***
# bb [add]
# black-body model
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │     bb      │  redshift   │  0.000  │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤═══════════════╕
# │  par#  │  Component  │  Parameter  │  Value  │     Prior     │
# ╞════════╪═════════════╪═════════════╪═════════╪═══════════════╡
# │   1    │     bb      │   log$kT$   │    1    │  unif(-2, 4)  │
# ├────────┼─────────────┼─────────────┼─────────┼───────────────┤
# │   2    │     bb      │   log$A$    │    0    │ unif(-10, 10) │
# ╘════════╧═════════════╧═════════════╧═════════╧═══════════════╛

# %%
cpl_ins = cpl()
cpl_ins.cfg[3].val = False
cpl_ins
# Out:
# *** Model ***
# cpl [add]
# power-law model with high-energy cutoff
# *** Model Configurations ***
# ╒════════╤═════════════╤══════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter   │  Value  │
# ╞════════╪═════════════╪══════════════╪═════════╡
# │   1    │     cpl     │   redshift   │  0.000  │
# ├────────┼─────────────┼──────────────┼─────────┤
# │   2    │     cpl     │ pivot_energy │  1.000  │
# ├────────┼─────────────┼──────────────┼─────────┤
# │   3    │     cpl     │   vfv_peak   │  False  │
# ╘════════╧═════════════╧══════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤═══════════════╕
# │  par#  │  Component  │  Parameter  │  Value  │     Prior     │
# ╞════════╪═════════════╪═════════════╪═════════╪═══════════════╡
# │   1    │     cpl     │  $\alpha$   │   -1    │  unif(-8, 4)  │
# ├────────┼─────────────┼─────────────┼─────────┼───────────────┤
# │   2    │     cpl     │  log$E_c$   │    2    │  unif(0, 4)   │
# ...

# %%
tbabs_ins = tbabs()
tbabs_ins
# Out:
# *** Model ***
# tbabs [mul]
# Tuebingen-Boulder ISM absorption model
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │    tbabs    │  redshift   │  0.000  │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤══════════════════╕
# │  par#  │  Component  │  Parameter  │  Value  │      Prior       │
# ╞════════╪═════════════╪═════════════╪═════════╪══════════════════╡
# │   1    │    tbabs    │    $N_H$    │    1    │ unif(0.0001, 50) │
# ╘════════╧═════════════╧═════════════╧═════════╧══════════════════╛

# %%
ztbabs_ins = tbabs()
ztbabs_ins.expr = 'ztbabs'
ztbabs_ins.config['redshift'].val = 1
ztbabs_ins
# Out:
# *** Model ***
# ztbabs [mul]
# Tuebingen-Boulder ISM absorption model
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │   ztbabs    │  redshift   │    1    │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤══════════════════╕
# │  par#  │  Component  │  Parameter  │  Value  │      Prior       │
# ╞════════╪═════════════╪═════════════╪═════════╪══════════════════╡
# │   1    │   ztbabs    │    $N_H$    │    1    │ unif(0.0001, 50) │
# ╘════════╧═════════════╧═════════════╧═════════╧══════════════════╛

# %% [markdown]
# astromodels

# %%
astro_models
# Out:
# {'AS_Blackbody': bayspec.model.astro.AS_Blackbody,
#  'AS_ModifiedBlackbody': bayspec.model.astro.AS_ModifiedBlackbody,
#  'AS_NonDissipativePhotosphere': bayspec.model.astro.AS_NonDissipativePhotosphere,
#  'AS_NonDissipativePhotosphere_Deep': bayspec.model.astro.AS_NonDissipativePhotosphere_Deep,
#  'AS_Log_parabola': bayspec.model.astro.AS_Log_parabola,
#  'AS_Exponential_cutoff': bayspec.model.astro.AS_Exponential_cutoff,
#  'AS_Powerlaw': bayspec.model.astro.AS_Powerlaw,
#  'AS_Powerlaw_flux': bayspec.model.astro.AS_Powerlaw_flux,
#  'AS_Powerlaw_Eflux': bayspec.model.astro.AS_Powerlaw_Eflux,
#  'AS_Cutoff_powerlaw': bayspec.model.astro.AS_Cutoff_powerlaw,
#  'AS_Cutoff_powerlaw_Ep': bayspec.model.astro.AS_Cutoff_powerlaw_Ep,
#  'AS_Inverse_cutoff_powerlaw': bayspec.model.astro.AS_Inverse_cutoff_powerlaw,
#  'AS_Super_cutoff_powerlaw': bayspec.model.astro.AS_Super_cutoff_powerlaw,
#  'AS_SmoothlyBrokenPowerLaw': bayspec.model.astro.AS_SmoothlyBrokenPowerLaw,
# ...

# %%
as_cpl_ins = AS_Cutoff_powerlaw()
as_cpl_ins.params['index'].val = -1
as_cpl_ins.params['xc'].val = 100
as_cpl_ins.params['logK'].val = 0
as_cpl_ins
# Out:
# *** Model ***
# AS_Cutoff_powerlaw [add]
# A power law multiplied by an exponential cutoff
# *** Model Configurations ***
# ╒════════╤════════════════════╤══════════════╤═════════╕
# │  cfg#  │     Component      │  Parameter   │  Value  │
# ╞════════╪════════════════════╪══════════════╪═════════╡
# │   1    │ AS_Cutoff_powerlaw │ pivot_energy │  1.000  │
# ├────────┼────────────────────┼──────────────┼─────────┤
# │   2    │ AS_Cutoff_powerlaw │   redshift   │    0    │
# ╘════════╧════════════════════╧══════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤════════════════════╤═════════════╤═════════╤═══════════════════╕
# │  par#  │     Component      │  Parameter  │  Value  │       Prior       │
# ╞════════╪════════════════════╪═════════════╪═════════╪═══════════════════╡
# │   1    │ AS_Cutoff_powerlaw │    logK     │    0    │ unif(-30.0, 3.0)  │
# ├────────┼────────────────────┼─────────────┼─────────┼───────────────────┤
# ...

# %%
as_tbabs_ins = AS_TbAbs()
as_tbabs_ins
# Out:
# *** Model ***
# AS_TbAbs [mul]
# Photometric absorption (Tbabs implementation), f(E) = exp(- NH * sigma(E)) contributed by Dominique Eckert
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │  AS_TbAbs   │  redshift   │  0.000  │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤══════════════════╕
# │  par#  │  Component  │  Parameter  │  Value  │      Prior       │
# ╞════════╪═════════════╪═════════════╪═════════╪══════════════════╡
# │   1    │  AS_TbAbs   │     NH      │  1.000  │ unif(0.0001, 20) │
# ╘════════╧═════════════╧═════════════╧═════════╧══════════════════╛

# %%
as_ztbabs_ins = AS_TbAbs()
as_ztbabs_ins.expr = 'AS_zTbAbs'
as_ztbabs_ins.config['redshift'].val = 1
as_ztbabs_ins
# Out:
# *** Model ***
# AS_zTbAbs [mul]
# Photometric absorption (Tbabs implementation), f(E) = exp(- NH * sigma(E)) contributed by Dominique Eckert
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │  AS_zTbAbs  │  redshift   │    1    │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤══════════════════╕
# │  par#  │  Component  │  Parameter  │  Value  │      Prior       │
# ╞════════╪═════════════╪═════════════╪═════════╪══════════════════╡
# │   1    │  AS_zTbAbs  │     NH      │  1.000  │ unif(0.0001, 20) │
# ╘════════╧═════════════╧═════════════╧═════════╧══════════════════╛

# %% [markdown]
# Xspec models
#
# NOTE:
#
# bayspec model integral method: integral(mo1 * mo2)
#
# xspec model integral method: integral(mo1) * integral(mo2) ~ integral(mo1 * mo2) when mo1 or mo2 is close to flat in energy bins
#
# how to use xspec model:
#
# option 1: differential integral(mo) of xspec to get mo, than integral(mo1 * mo2)
#
# option 2: integral mo, then integral(mo1) * integral(mo2)
#
# I CHOOSE OPTION ONE

# %%
xspec_models
# Out:
# {'XS_agauss': bayspec.model.xspec.XS_agauss,
#  'XS_agnsed': bayspec.model.xspec.XS_agnsed,
#  'XS_agnslim': bayspec.model.xspec.XS_agnslim,
#  'XS_apec': bayspec.model.xspec.XS_apec,
#  'XS_bapec': bayspec.model.xspec.XS_bapec,
#  'XS_bbody': bayspec.model.xspec.XS_bbody,
#  'XS_bbodyrad': bayspec.model.xspec.XS_bbodyrad,
#  'XS_bcempow': bayspec.model.xspec.XS_bcempow,
#  'XS_bcheb6': bayspec.model.xspec.XS_bcheb6,
#  'XS_bcie': bayspec.model.xspec.XS_bcie,
#  'XS_bcoolflow': bayspec.model.xspec.XS_bcoolflow,
#  'XS_bcph': bayspec.model.xspec.XS_bcph,
#  'XS_bequil': bayspec.model.xspec.XS_bequil,
#  'XS_bexpcheb6': bayspec.model.xspec.XS_bexpcheb6,
#  'XS_bexrav': bayspec.model.xspec.XS_bexrav,
#  'XS_bexriv': bayspec.model.xspec.XS_bexriv,
#  'XS_bgadem': bayspec.model.xspec.XS_bgadem,
#  'XS_bgnei': bayspec.model.xspec.XS_bgnei,
#  'XS_bkn2pow': bayspec.model.xspec.XS_bkn2pow,
#  'XS_bknpower': bayspec.model.xspec.XS_bknpower,
#  'XS_bmc': bayspec.model.xspec.XS_bmc,
# ...

# %%
len(xspec_models)
# Out:
# 270

# %%
xs_cutoffpl_ins = XS_cutoffpl()
xs_cutoffpl_ins.params['PhoIndex'].val = 1
xs_cutoffpl_ins.params['HighECut'].val = 100
xs_cutoffpl_ins.params['logNorm'].val = 0
xs_cutoffpl_ins
# Out:
# *** Model ***
# XS_cutoffpl [add]
# xspec model cutoffpl
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │ XS_cutoffpl │  redshift   │    0    │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤══════════════════╕
# │  par#  │  Component  │  Parameter  │  Value  │      Prior       │
# ╞════════╪═════════════╪═════════════╪═════════╪══════════════════╡
# │   1    │ XS_cutoffpl │  PhoIndex   │    1    │ unif(-2.0, 9.0)  │
# ├────────┼─────────────┼─────────────┼─────────┼──────────────────┤
# │   2    │ XS_cutoffpl │  HighECut   │   100   │ unif(1.0, 500.0) │
# ├────────┼─────────────┼─────────────┼─────────┼──────────────────┤
# │   3    │ XS_cutoffpl │   logNorm   │    0    │  unif(-10, 10)   │
# ...

# %%
abund('wilm')
xsect('vern')
# Out:
#  Solar Abundance Vector set to angr:  Anders E. & Grevesse N. Geochimica et Cosmochimica Acta 53, 197 (1989)
#  Cross Section Table set to vern:  Verner, Ferland, Korista, and Yakovlev 1996
#  Solar Abundance Vector set to wilm:  Wilms, J., Allen, A. & McCray, R. ApJ 542 914 (2000) (abundances are set to zero for those elements not included in the paper).
#  Cross Section Table set to vern:  Verner, Ferland, Korista, and Yakovlev 1996

# %%
xs_tbabs_ins = XS_TBabs()
xs_tbabs_ins
# Out:
# *** Model ***
# XS_TBabs [mul]
# xspec model TBabs
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │  XS_TBabs   │  redshift   │    0    │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤═════════════════════╕
# │  par#  │  Component  │  Parameter  │  Value  │        Prior        │
# ╞════════╪═════════════╪═════════════╪═════════╪═════════════════════╡
# │   1    │  XS_TBabs   │     nH      │  1.000  │ unif(0.0, 100000.0) │
# ╘════════╧═════════════╧═════════════╧═════════╧═════════════════════╛

# %%
xs_ztbabs_ins = XS_zTBabs()
xs_ztbabs_ins.config['redshift'].val = 1
xs_ztbabs_ins
# Out:
# *** Model ***
# XS_zTBabs [mul]
# xspec model zTBabs
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │  XS_zTBabs  │  redshift   │    1    │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤═════════════════════╕
# │  par#  │  Component  │  Parameter  │  Value  │        Prior        │
# ╞════════╪═════════════╪═════════════╪═════════╪═════════════════════╡
# │   1    │  XS_zTBabs  │     nH      │  1.000  │ unif(0.0, 100000.0) │
# ╘════════╧═════════════╧═════════════╧═════════╧═════════════════════╛

# %% [markdown]
# comparing same models from different library

# %%
earr = np.logspace(1, 3, 1000)

modelplot = Plot.model(ploter='plotly', style='NE', post=False)
modelplot.add_model(cpl_ins, E=earr)
modelplot.add_model(as_cpl_ins, E=earr)
modelplot.add_model(xs_cutoffpl_ins, E=earr)
fig = modelplot.get_fig()

# %%
earr = np.logspace(-1, 1, 1000)

modelplot = Plot.model(ploter='plotly', style='NoU', post=False, yrange=[1e-15, 1e1])
modelplot.add_model(tbabs_ins, E=earr)
modelplot.add_model(ztbabs_ins, E=earr)
modelplot.add_model(as_tbabs_ins, E=earr)
modelplot.add_model(as_ztbabs_ins, E=earr)
modelplot.add_model(xs_tbabs_ins, E=earr)
modelplot.add_model(xs_ztbabs_ins, E=earr)
fig = modelplot.get_fig()

# %% [markdown]
# composite model

# %%
mo = as_tbabs_ins * xs_ztbabs_ins * (xs_cutoffpl_ins + bb_ins)
mo
# Out:
# *** Model ***
# ((AS_TbAbs*XS_zTBabs)*(XS_cutoffpl+bb)) [add]
# AS_TbAbs: Photometric absorption (Tbabs implementation), f(E) = exp(- NH * sigma(E)) contributed by Dominique Eckert
# XS_zTBabs: xspec model zTBabs
# XS_cutoffpl: xspec model cutoffpl
# bb: black-body model
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │  AS_TbAbs   │  redshift   │  0.000  │
# ├────────┼─────────────┼─────────────┼─────────┤
# │   2    │  XS_zTBabs  │  redshift   │    1    │
# ├────────┼─────────────┼─────────────┼─────────┤
# │   3    │ XS_cutoffpl │  redshift   │    0    │
# ├────────┼─────────────┼─────────────┼─────────┤
# │   4    │     bb      │  redshift   │  0.000  │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤═════════════════════╕
# ...

# %%
mo.cfg[3].val = 0.065
mo.par[1].frozen_at(0.126)
mo
# Out:
# *** Model ***
# ((AS_TbAbs*XS_zTBabs)*(XS_cutoffpl+bb)) [add]
# AS_TbAbs: Photometric absorption (Tbabs implementation), f(E) = exp(- NH * sigma(E)) contributed by Dominique Eckert
# XS_zTBabs: xspec model zTBabs
# XS_cutoffpl: xspec model cutoffpl
# bb: black-body model
# *** Model Configurations ***
# ╒════════╤═════════════╤═════════════╤═════════╕
# │  cfg#  │  Component  │  Parameter  │  Value  │
# ╞════════╪═════════════╪═════════════╪═════════╡
# │   1    │  AS_TbAbs   │  redshift   │  0.000  │
# ├────────┼─────────────┼─────────────┼─────────┤
# │   2    │  XS_zTBabs  │  redshift   │    1    │
# ├────────┼─────────────┼─────────────┼─────────┤
# │   3    │ XS_cutoffpl │  redshift   │  0.065  │
# ├────────┼─────────────┼─────────────┼─────────┤
# │   4    │     bb      │  redshift   │  0.000  │
# ╘════════╧═════════════╧═════════════╧═════════╛
# *** Model Parameters ***
# ╒════════╤═════════════╤═════════════╤═════════╤═════════════════════╕
# ...
