# %%
import matplotlib.pyplot as plt
import numpy as np

from bayspec.util.prior import *

# %%
list_priors()
# Out:
# ['unif',
#  'logunif',
#  'norm',
#  'lognorm',
#  'truncnorm',
#  'cauchy',
#  'cosine',
#  'beta',
#  'gamma',
#  'expon',
#  'plaw']

# %% [markdown]
# uniform prior

# %%
unif_prior = unif(1, 10)

r = np.random.rand(10000)
x = np.linspace(unif_prior.ppf(0.01), unif_prior.ppf(0.99), 1000)

fig, ax = plt.subplots(1, 1, dpi=100)
ax.plot(x, unif_prior.pdf(x), 'r-', lw=3, alpha=1.0, label=unif_prior.info)
ax.hist(
    unif_prior.ppf(r),
    density=True,
    bins='auto',
    histtype='stepfilled',
    alpha=0.5,
    label='transform',
)
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# normal prior

# %%
norm_prior = norm(2, 5)

r = np.random.rand(10000)
x = np.linspace(norm_prior.ppf(0.01), norm_prior.ppf(0.99), 1000)

fig, ax = plt.subplots(1, 1, dpi=100)
ax.plot(x, norm_prior.pdf(x), 'r-', lw=3, alpha=1.0, label=norm_prior.info)
ax.hist(
    norm_prior.ppf(r),
    density=True,
    bins='auto',
    histtype='stepfilled',
    alpha=0.5,
    label='transform',
)
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# truncated normal prior

# %%
truncnorm_prior = truncnorm(-1, 1, 2, 5)

r = np.random.rand(10000)
x = np.linspace(truncnorm_prior.ppf(0.01), truncnorm_prior.ppf(0.99), 1000)

fig, ax = plt.subplots(1, 1, dpi=100)
ax.plot(x, truncnorm_prior.pdf(x), 'r-', lw=3, alpha=1.0, label=truncnorm_prior.info)
ax.hist(
    truncnorm_prior.ppf(r),
    density=True,
    bins='auto',
    histtype='stepfilled',
    alpha=0.5,
    label='transform',
)
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# Cauchy prior

# %%
cauchy_prior = cauchy(0, 1)

r = np.random.rand(1000)
x = np.linspace(cauchy_prior.ppf(0.01), cauchy_prior.ppf(0.99), 1000)

fig, ax = plt.subplots(1, 1, dpi=100)
ax.plot(x, cauchy_prior.pdf(x), 'r-', lw=3, alpha=1.0, label=cauchy_prior.info)
ax.hist(
    cauchy_prior.ppf(r),
    density=True,
    bins='auto',
    histtype='stepfilled',
    alpha=0.5,
    label='transform',
)
ax.legend(loc='best', frameon=False)
ax.set_xlim([-20, 20])
plt.show()

# %% [markdown]
# cosine prior

# %%
cosine_prior = cosine(0, 1)

r = np.random.rand(1000)
x = np.linspace(cosine_prior.ppf(0.01), cosine_prior.ppf(0.99), 1000)

fig, ax = plt.subplots(1, 1, dpi=100)
ax.plot(x, cosine_prior.pdf(x), 'r-', lw=3, alpha=1.0, label=cosine_prior.info)
ax.hist(
    cosine_prior.ppf(r),
    density=True,
    bins='auto',
    histtype='stepfilled',
    alpha=0.5,
    label='transform',
)
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# beta prior

# %%
beta_prior = beta(2.31, 0.627, 0, 1)

r = np.random.rand(10000)
x = np.linspace(beta_prior.ppf(0.01), beta_prior.ppf(0.99), 1000)

fig, ax = plt.subplots(1, 1, dpi=100)
ax.plot(x, beta_prior.pdf(x), 'r-', lw=3, alpha=1.0, label=beta_prior.info)
ax.hist(
    beta_prior.ppf(r),
    density=True,
    bins='auto',
    histtype='stepfilled',
    alpha=0.5,
    label='transform',
)
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# gamma prior

# %%
gamma_prior = gamma(1.99, 0, 1)

r = np.random.rand(10000)
x = np.linspace(gamma_prior.ppf(0.01), gamma_prior.ppf(0.99), 1000)

fig, ax = plt.subplots(1, 1, dpi=100)
ax.plot(x, gamma_prior.pdf(x), 'r-', lw=3, alpha=1.0, label=gamma_prior.info)
ax.hist(
    gamma_prior.ppf(r),
    density=True,
    bins='auto',
    histtype='stepfilled',
    alpha=0.5,
    label='transform',
)
ax.legend(loc='best', frameon=False)
plt.show()
